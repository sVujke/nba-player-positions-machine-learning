# %%
import numpy as np

from pandas import Series,DataFrame
import pandas as pd

# %%
df = pd.read_csv('test.txt', sep="\t")

df
# Out:
#               SF\tP.J. Tucker
# 0              F\tBobby Jones
# 1             PF\tCraig Smith
# 2            C\tKosta Perovic
# 3         FC\tJames Augustine
# 4            G\tDaniel Gibson
# 5           PF\tDamir Markota
# 6            GF\tDenham Brown
# 7          F\tMarcus Vinicius
# 8            PF\tLior Eliyahu
# 9        F\tAlexander Johnson
# 10               G\tDee Brown
# 11           FC\tPaul Millsap
# 12    PF\tVladimir Veremeenko
# 13               F\tLeon Powe
# 14            C\tRyan Hollins
# 15            C\tCheickh Samb
# 16          G\tGuillermo Diaz
# 17         SG\tYotam Halperin
# 18            G\tHassan Adams
# 19           F\tEjike Ugboaja
# 20             C\tEdin Bavcic
# 21   C\tLoukas Mavrokefalidis
# 22           SG\tJ.R. Pinnock
# 23            G\tWill Blalock
# 24             GF\tC.J. Miles
# 25           PF\tBrandon Bass
# 26            G\tDaniel Ewing
# 27          F\tErsan Ilyasova
# 28             G\tMonta Ellis
# 29           FC\tRonny Turiaf
# ...
